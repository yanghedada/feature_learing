# %%
import pandas as pd

# %%
train_data =  pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test_data.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
#第一种方法

# %%
train_data['month'] = pd.DatetimeIndex(train_data.datetime).month
train_data['day'] = pd.DatetimeIndex(train_data.datetime).day
train_data['hour'] = pd.DatetimeIndex(train_data.datetime).hour
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  month  day  hour
# 0        81        0.0       3          13     16      1    1     0
# 1        80        0.0       8          32     40      1    1     1
# 2        80        0.0       5          27     32      1    1     2
# 3        75        0.0       3          10     13      1    1     3
# 4        75        0.0       0           1      1      1    1     4

# %%
#第二种方法

# %%
train_data =  pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
from datetime import datetime
train_data['week'] = [datetime.date(datetime.strptime(time, '%Y-%m-%d')).weekday()  for time in train_data['datetime'].str[:10]]  
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  week
# 0        81        0.0       3          13     16     5
# 1        80        0.0       8          32     40     5
# 2        80        0.0       5          27     32     5
# 3        75        0.0       3          10     13     5
# 4        75        0.0       0           1      1     5

# %%
train_data['hour'] = train_data['datetime'].str[11:13].astype(int)
train_data['year'] = train_data['datetime'].str[0:4].astype(int)
train_data['month'] = train_data['datetime'].str[5:7].astype(int)
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  week  hour  year  month
# 0        81        0.0       3          13     16     5     0  2011      1
# 1        80        0.0       8          32     40     5     1  2011      1
# 2        80        0.0       5          27     32     5     2  2011      1
# 3        75        0.0       3          10     13     5     3  2011      1
# 4        75        0.0       0           1      1     5     4  2011      1

# %%
#第三种方法

# %%
train_data =  pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
time = pd.DatetimeIndex(train_data['datetime'])
train_data['year'] = time.year
train_data['month'] = time.month
train_data['hour'] = time.hour
train_data['weekday'] = time.weekday
train_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  hour  weekday
# 0        81        0.0       3          13     16  2011      1     0        5
# 1        80        0.0       8          32     40  2011      1     1        5
# 2        80        0.0       5          27     32  2011      1     2        5
# 3        75        0.0       3          10     13  2011      1     3        5
# 4        75        0.0       0           1      1  2011      1     4        5
